# %%
import pandas as pd

# %%
# load data
atp_path = "./atp_men/"
wta_path = "./wta_women/"

atp_2023 = pd.read_excel(atp_path + "2023.xlsx")
wta_2023 = pd.read_excel(wta_path + "2023.xlsx")
print("atp_2023: ", atp_2023.shape)
print("wta_2023: ", wta_2023.shape, "\n")

atp_2024 = pd.read_excel(atp_path + "2024.xlsx")
wta_2024 = pd.read_excel(wta_path + "2024.xlsx")
print("atp_2024: ", atp_2024.shape)
print("wta_2024: ", wta_2024.shape, "\n")

atp_2025 = pd.read_excel(atp_path + "2025.xlsx")
wta_2025 = pd.read_excel(wta_path + "2025.xlsx")
print("atp_2025: ", atp_2025.shape)
print("wta_2025: ", wta_2025.shape, "\n")

# merge atp and wta data
atp_all = pd.concat([atp_2023, atp_2024, atp_2025])
wta_all = pd.concat([wta_2023, wta_2024, wta_2025])

# save data
atp_all.to_csv("./atp_men/atp_2023-2025.csv", index=False)
wta_all.to_csv("./wta_women/wta_2023-2025.csv", index=False)
# Out:
# atp_2023:  (2703, 36)
# wta_2023:  (2491, 32)
#
# atp_2024:  (2703, 36)
# wta_2024:  (2490, 32)
#
# atp_2025:  (1493, 36)
# wta_2025:  (1424, 32)

# %%
atp_all
# Out:
#       ATP  Location                Tournament       Date  Series    Court  \
# 0       1  Adelaide  Adelaide International 1 2023-01-01  ATP250  Outdoor
# 1       1  Adelaide  Adelaide International 1 2023-01-01  ATP250  Outdoor
# 2       1  Adelaide  Adelaide International 1 2023-01-02  ATP250  Outdoor
# 3       1  Adelaide  Adelaide International 1 2023-01-02  ATP250  Outdoor
# 4       1  Adelaide  Adelaide International 1 2023-01-02  ATP250  Outdoor
# ...   ...       ...                       ...        ...     ...      ...
# 1488   35  Mallorca    Mallorca Championships 2025-06-26  ATP250  Outdoor
# 1489   35  Mallorca    Mallorca Championships 2025-06-26  ATP250  Outdoor
# 1490   35  Mallorca    Mallorca Championships 2025-06-27  ATP250  Outdoor
# 1491   35  Mallorca    Mallorca Championships 2025-06-27  ATP250  Outdoor
# 1492   35  Mallorca    Mallorca Championships 2025-06-28  ATP250  Outdoor
#
#      Surface          Round  Best of         Winner  ... Lsets    Comment  \
# 0       Hard      1st Round        3       Giron M.  ...   1.0  Completed
# 1       Hard      1st Round        3    Mcdonald M.  ...   0.0    Retired
# 2       Hard      1st Round        3  Kecmanovic M.  ...   0.0  Completed
# 3       Hard      1st Round        3    Nishioka Y.  ...   1.0  Completed
# 4       Hard      1st Round        3     Popyrin A.  ...   0.0  Completed
# ...      ...            ...      ...            ...  ...   ...        ...
# 1488   Grass  Quarterfinals        3      Moutet C.  ...   0.0  Completed
# 1489   Grass  Quarterfinals        3   Michelsen A.  ...   0.0  Completed
# 1490   Grass     Semifinals        3  Griekspoor T.  ...   0.0  Completed
# 1491   Grass     Semifinals        3      Moutet C.  ...   0.0  Completed
# 1492   Grass      The Final        3  Griekspoor T.  ...   0.0  Completed
#
#       B365W  B365L   PSW   PSL  MaxW  MaxL  AvgW  AvgL
# 0      1.91   1.91  1.93  1.95  1.99  1.95  1.89  1.89
# 1      1.36   3.20  1.39  3.25  1.44  3.40  1.36  3.12
# 2      1.57   2.38  1.58  2.53  1.64  2.53  1.58  2.36
# 3      3.75   1.29  4.00  1.28  4.00  1.31  3.56  1.29
# 4      6.50   1.11  6.20  1.15  6.75  1.18  6.04  1.13
# ...     ...    ...   ...   ...   ...   ...   ...   ...
# 1488   2.10   1.75  2.17  1.78  2.17  1.85  2.04  1.77
# 1489   1.95   1.85  1.99  1.91  2.02  1.96  1.89  1.89
# 1490   2.20   1.67  2.30  1.69  2.32  1.74  2.18  1.67
# 1491   2.40   1.57  2.52  1.60  2.52  1.66  2.39  1.56
# 1492   1.57   2.30  1.59  2.46  1.65  2.50  1.56  2.39
#
# [6899 rows x 36 columns]

# %%
wta_all
# Out:
#       WTA    Location                Tournament       Date    Tier    Court  \
# 0       1    Adelaide  Adelaide International 1 2023-01-01  WTA500  Outdoor
# 1       1    Adelaide  Adelaide International 1 2023-01-01  WTA500  Outdoor
# 2       1    Adelaide  Adelaide International 1 2023-01-02  WTA500  Outdoor
# 3       1    Adelaide  Adelaide International 1 2023-01-02  WTA500  Outdoor
# 4       1    Adelaide  Adelaide International 1 2023-01-02  WTA500  Outdoor
# ...   ...         ...                       ...        ...     ...      ...
# 1419   30  Eastbourne           Eastbourne Open 2025-06-26  WTA250  Outdoor
# 1420   30  Eastbourne           Eastbourne Open 2025-06-26  WTA250  Outdoor
# 1421   30  Eastbourne           Eastbourne Open 2025-06-27  WTA250  Outdoor
# 1422   30  Eastbourne           Eastbourne Open 2025-06-27  WTA250  Outdoor
# 1423   30  Eastbourne           Eastbourne Open 2025-06-28  WTA250  Outdoor
#
#      Surface          Round  Best of             Winner  ... Lsets    Comment  \
# 0       Hard      1st Round        3       Andreescu B.  ...   1.0  Completed
# 1       Hard      1st Round        3          Kanepi K.  ...   1.0  Completed
# 2       Hard      1st Round        3         Noskova L.  ...   1.0  Completed
# 3       Hard      1st Round        3            Begu I.  ...   1.0  Completed
# 4       Hard      1st Round        3     Kudermetova V.  ...   0.0  Completed
# ...      ...            ...      ...                ...  ...   ...        ...
# 1419   Grass  Quarterfinals        3            Eala A.  ...   0.0  Completed
# 1420   Grass  Quarterfinals        3  Pavlyuchenkova A.  ...   1.0  Completed
# 1421   Grass     Semifinals        3            Eala A.  ...   1.0  Completed
# 1422   Grass     Semifinals        3           Joint M.  ...   0.0  Completed
# 1423   Grass      The Final        3           Joint M.  ...   1.0  Completed
#
#       B365W  B365L   PSW   PSL  MaxW  MaxL  AvgW  AvgL
# 0      1.50   2.63  1.52  2.70   1.6  2.70  1.51  2.55
# 1      1.91   1.91  1.96  1.93   2.0  1.95  1.90  1.89
# 2      3.40   1.33  3.25  1.39   3.4  1.41  3.04  1.37
# 3      2.75   1.44  2.97  1.44  2.97  1.56  2.66  1.47
# 4      1.53   2.50  1.53  2.66  1.58  2.66  1.52  2.48
# ...     ...    ...   ...   ...   ...   ...   ...   ...
# 1419   2.30   1.57  2.34  1.68   2.5  1.68  2.38  1.57
# 1420   1.62   2.30  1.66  2.37  1.68  2.44  1.63  2.27
# 1421   1.45   2.80  1.49  2.83  1.49  2.83  1.45  2.71
# 1422   1.57   2.30  1.63  2.45  1.64  2.52  1.60  2.32
# 1423   1.62   2.20  1.69  2.31  1.72  2.38  1.64  2.24
#
# [6405 rows x 32 columns]

# %%
atp_all.columns
# Out:
# Index(['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface',
#        'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts',
#        'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets',
#        'Lsets', 'Comment', 'B365W', 'B365L', 'PSW', 'PSL', 'MaxW', 'MaxL',
#        'AvgW', 'AvgL'],
#       dtype='object')

# %%
wta_all.columns
# Out:
# Index(['WTA', 'Location', 'Tournament', 'Date', 'Tier', 'Court', 'Surface',
#        'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts',
#        'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'Wsets', 'Lsets', 'Comment',
#        'B365W', 'B365L', 'PSW', 'PSL', 'MaxW', 'MaxL', 'AvgW', 'AvgL'],
#       dtype='object')
